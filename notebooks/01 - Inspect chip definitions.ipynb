# %% [markdown]
# #### Before running anything - there are two extra libraries to install for the visualisations in these notebooks

# %%
# !pip install folium mapclassify
# Out:
# Requirement already satisfied: folium in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: mapclassify in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: branca>=0.6.0 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from folium) (2024.6.0)
# Requirement already satisfied: networkx>=2.7 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from mapclassify) (3.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from mapclassify) (1.5.0)
# Requirement already satisfied: scipy>=1.8 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from mapclassify) (1.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from requests->folium) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /home/matt/miniconda3/envs/m3leo-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %%
import geopandas as gpd
import pandas as pd
from shapely import wkt
import matplotlib.colors as colors

from huggingface_hub import hf_hub_download

# %% [markdown]
# ### Download definition files
#
# Two definition files are required
#
# - One file (.geojson) outlining the geographic extent of each tile
# - One file (.csv) giving the train/test/validation split for each tile
#
# Each file is indexed by the alphanumeric identifier of the tile. Each datachip corresponding to a fixed geographic tile (i.e the same physical space on the surface of the Earth) has the same identifier across all component datasets (e.g. S1GRD, S2RGB etc.)

# %%
#Name of huggingface repo
HUGGINGFACE_REPO_ID = "M3LEO-miniset/conus"

#Relevant files to retrieve
chipdefs_remote = 'conus_partitions_aschips_293d95e3ee589_miniset.geojson'
splitdefs_remote = 'conus_partitions_aschips_293d95e3ee589_splits_60bands_angle09_60-20-20_miniset.csv'

# %% [markdown]
# We download the relevant files from the HuggingFace repository using hf_hub_download():

# %%
chipdefs_local = hf_hub_download(repo_id=HUGGINGFACE_REPO_ID, filename=chipdefs_remote, repo_type='dataset')
splitdefs_local = hf_hub_download(repo_id=HUGGINGFACE_REPO_ID, filename=splitdefs_remote, repo_type='dataset')

print(f"Chip definitions downloaded to {chipdefs_local}")
print(f"Split definitions downloaded to {splitdefs_local}")
# Out:
# Chip definitions downloaded to /home/matt/.cache/huggingface/hub/datasets--M3LEO-miniset--conus/snapshots/a5b2fc3f3e08e4e58f4038f3969b93beaab7d168/conus_partitions_aschips_293d95e3ee589_miniset.geojson
# Split definitions downloaded to /home/matt/.cache/huggingface/hub/datasets--M3LEO-miniset--conus/snapshots/a5b2fc3f3e08e4e58f4038f3969b93beaab7d168/conus_partitions_aschips_293d95e3ee589_splits_60bands_angle09_60-20-20_miniset.csv

# %% [markdown]
# ### Load tile definitions

# %%
tiles_df = gpd.read_file(chipdefs_local)
splits_df = pd.read_csv(splitdefs_local)

# %% [markdown]
# We can now see that the that the tiles definition file contains the geometry of each file. Note that, for the miniset, we store the index of the tiles as they are found in the full dataset under original_index. You can ignore it for the rest of these notebooks.

# %%
tiles_df.head()
# Out:
#     area_km2     identifier  original_index  \
# 0  21.965738  0141dce56d692               6
# 1  21.929954  197e06c26aa3d              25
# 2  21.938541  142643de7174a              52
# 3  21.959804  2018fe7c56825              56
# 4  21.692478  112f75269df78              98
#
#                                             geometry
# 0  POLYGON ((-124.42348 40.41738, -124.42348 40.4...
# 1  POLYGON ((-124.26954 40.29386, -124.26954 40.3...
# 2  POLYGON ((-124.26562 40.41450, -124.26562 40.4...
# 3  POLYGON ((-124.32435 40.56045, -124.32435 40.6...
# 4  POLYGON ((-123.51304 38.71519, -123.51304 38.7...

# %% [markdown]
# The splits definition file lists the split for each tile:

# %%
splits_df.head()
# Out:
#       identifier  split  original_index
# 0  020d259a89240  train           41505
# 1  1e92ebf944d4d  train           59541
# 2  1440370d0d286  train           69697
# 3  11627afc2a613  train          131544
# 4  057aa09d02a81  train          146310

# %% [markdown]
# ### Visualize tiles
#
# There are a lot of them, even for the miniset. We've provided a .wkt file describing Massachusetts, which we'll use to limit the AOI in these notebooks. We'll also colour them by split, by merging the two dataframes.

# %%
#limit to massachusetts
with open('../data/massachusetts.wkt') as f:
    bounds = wkt.load(f)

tiles_df = tiles_df[tiles_df.intersects(bounds)]
chips_splits_df = tiles_df.merge(splits_df, on='identifier')
chips_splits_df.explore(column='split', cmap=colors.ListedColormap(['red','blue', 'green']))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36ffafb9fc248af23d16e47a98b01eaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend split&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;split&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;test&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#0000ff&#x27;&gt;&lt;/span&gt;train&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#008000&#x27;&gt;&lt;/span&gt;val&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36ffafb9fc248af23d16e47a98b01eaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36ffafb9fc248af23d16e47a98b01eaa = L.map(
#                 &quot;map_36ffafb9fc248af23d16e47a98b01eaa&quot;,
#                 {
#                     center: [42.15879557970566, -71.90004237538491],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_36ffafb9fc248af23d16e47a98b01eaa);
#
#
#
#
#
#             var tile_layer_e251b584df672f6a55899157b6498409 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e251b584df672f6a55899157b6498409.addTo(map_36ffafb9fc248af23d16e47a98b01eaa);
#
#
#             map_36ffafb9fc248af23d16e47a98b01eaa.fitBounds(
#                 [[41.51799810051397, -73.43531971494377], [42.79959305889735, -70.36476503582605]],
#                 {}
#             );
#
#
#         function geo_json_fcde2e44e979dc90c6ad61fbec03efb1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;13&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#ff0000&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;4&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot
